# %% [markdown]
# # 1. Import required libraries

# %%
import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Read csv

# %%
df = pd.read_csv (r"/content/charcters_stats.csv")
print(df)
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# 1       17      64    316
# 2       35      85    299
# 3       84      65    406
# 4       55      95    436
# ..     ...     ...    ...
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292
# 610     72      28    288
#
# [611 rows x 9 columns]

# %% [markdown]
# # 3. Show first records from csv

# %%
df.head(10)
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0       3-D Man      good            50        31     43          32     25
# 1        A-Bomb      good            38       100     17          80     17
# 2    Abe Sapien      good            88        14     35          42     35
# 3      Abin Sur      good            50        90     53          64     84
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 6   Adam Monroe      good            63        10     12         100     71
# 7  Adam Strange      good             1         1      1           1      0
# 8     Agent  13      good             1         1      1           1      0
# 9     Agent Bob      good            10         8     13           5      5
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436
# 5      56    526
# 6      64    320
# 7       1      5
# 8       1      5
# 9      20     61

# %% [markdown]
# # 4. Show number of rows and columns

# %%
row_count = len(df) # Return number of rows
row_count
# Out:
# 611

# %%
col_count = len(df.columns) # Return number of columns
col_count
# Out:
# 9

# %% [markdown]
# # 5. You need to find the values of alignment ,can use value_counts()

# %%
df.Alignment.value_counts()
# Out:
# good       432
# bad        165
# neutral     11
# Name: Alignment, dtype: int64

# %% [markdown]
# # 6. Find out only good alignment holders superheroes

# %%
good_alignment = df.query("Alignment == 'good'")
good_alignment
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# 1       17      64    316
# 2       35      85    299
# 3       84      65    406
# 6       71      64    320
# ..     ...     ...    ...
# 604     92      84    465
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292
#
# [432 rows x 9 columns]

# %% [markdown]
# # 7. Show first five records which you found in point 6

# %%
good_alignment = df.query("Alignment == 'good'")
good_alignment.head(5)
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %% [markdown]
# # 8. Show top five records having top speed of heroes of good alignment

# %%
fast_hero = good_alignment.groupby(['Name', 'Speed'])['Speed'].max().nlargest(5)
fast_hero
# Out:
# Name        Speed
# Black Bolt  100      100
# Flash I     100      100
# Flash II    100      100
# Flash III   100      100
# Flash IV    100      100
# Name: Speed, dtype: int64

# %% [markdown]
# # 9.Show 5 records of super heroes who have maximum power of good alignment

# %%
good_alignment.groupby(['Name', 'Power'])['Power'].max().nlargest(5)
# Out:
# Name           Power
# Beta Ray Bill  100      100
# Beyonder       100      100
# Black Bolt     100      100
# Cable          100      100
# Deadman        100      100
# Name: Power, dtype: int64

# %% [markdown]
# # 10. Find out how many super heroes are there with power 100 of good alignment

# %%
max_power = good_alignment.query("Power == 100 ")
max_power.count()
# Out:
# Name            33
# Alignment       33
# Intelligence    33
# Strength        33
# Speed           33
# Durability      33
# Power           33
# Combat          33
# Total           33
# dtype: int64

# %% [markdown]
# # 11. Shape them what you got in point 10

# %%
max_power.count().plot.pie(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2a5fe12850>],
#       dtype=object)

# %% [markdown]
# # 12. Show all records from point 10

# %%
max_power
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# 294             Iceman      good            63        32     53         100
# 299           Iron Man      good           100        85     58          85
# 306          Jean Grey      good           100        80     67         100
# 327            Kilowog      good            81        90     53          42
# 361  Martian Manhunter      good           100       100     96         100
# 362        Marvel Girl      good            63        85     47          42
# 383       Miss Martian      good            63        85     58         100
# 408     Naruto Uzumaki      good            50        80     32          80
# 417               Nova      good           100        85     67         101
# 418               Nova      good            38        60    100         100
# 419          Offspring      good            50        10     35          99
# 433            Phoenix      good           100        80     67         100
# 435        Plastic Man      good            50        63     23         100
# 487        Shadow King      good            75        12     27         100
# 499      Silver Surfer      good            63       100     84         101
# 511              Spawn      good            75        60     50          90
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 547          Thor Girl      good            75        83     70          84
# 583        War Machine      good            63        80     63         100
# 589            Watcher      good           100        80     67          89
# 609            Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335
# 196    100      50    352
# 198    100      60    366
# 204    100      42    399
# 226    100      42    359
# 251    100     100    521
# 266    100      56    426
# 294    100      64    412
# 299    100      64    492
# 306    100      70    517
# 327    100      80    446
# 361    100      85    581
# 362    100      80    417
# 383    100      45    451
# 408    100     100    442
# 417    100      85    538
# 418    100      25    423
# 419    100      56    350
# 433    100      70    517
# 435    100      56    392
# 487    100      75    389
# 499    100      32    480
# 511    100      95    470
# 525    100      85    568
# 546    100      85    546
# 547    100      70    482
# 583    100      85    491
# 589    100      56    492
# 609    100      56    292

# %% [markdown]
# # 13. Retrieve total of first five records of max power of good alignment super heroes

# %%
max_power.head(5)
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
# 85      Black Bolt      good            75        67    100          84
# 129          Cable      good            88        48     23          56
# 185        Deadman      good            50        10     33         100
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335

# %% [markdown]
# # 14. Draw a bar plot of all super heroes who are having good alignment and max power of top five only , take same object of point 13 , show name and total in plot with green bars

# %%
max_power.groupby('Name')['Total'].max().nlargest(5).plot.bar(stacked=True, color = ('green'))

# %% [markdown]
# # 15. Extract villains having bad alignment

# %%
Villans = df.query("Alignment == 'bad'")
Villans
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# 11     100      40    460
# 16     100     100    575
# 17       0       1      5
# ..     ...     ...    ...
# 586     63      50    212
# 590      0       1      5
# 593     41      60    206
# 605      0       1      5
# 610     72      28    288
#
# [165 rows x 9 columns]

# %% [markdown]
# # 16. Show first five records of point 15

# %%
Villans.head(5)
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %% [markdown]
# # 17. Show top five fastest super villains in terms of super speed

# %%
fast_villan = Villans.groupby(['Name', 'Speed'])['Speed'].max().nlargest(5)
fast_villan
# Out:
# Name            Speed
# Air-Walker      100      100
# Amazo           100      100
# Superboy-Prime  100      100
# Zoom            100      100
# General Zod     96        96
# Name: Speed, dtype: int64

# %% [markdown]
# # 18. Top five super villains in terms of intelligence

# %%
Villans.groupby(['Name', 'Intelligence'])['Intelligence'].max().nlargest(5)
# Out:
# Name             Intelligence
# Mister Mxyzptlk  113             113
# Apocalypse       100             100
# Brainiac         100             100
# Doctor Doom      100             100
# Joker            100             100
# Name: Intelligence, dtype: int64

# %% [markdown]
# # 19. Show who is most dangerous super villain after calculating their total (top 5 only)

# %%
Villans.groupby(['Name', 'Total'])['Total'].max().nlargest(5)
# Out:
# Name            Total
# General Zod     579      579
# Superboy-Prime  579      579
# Amazo           575      575
# Dormammu        546      546
# Doomsday        545      545
# Name: Total, dtype: int64

# %% [markdown]
# # 20. Draw a histogram for speed of super heroes having fig size 10,5 , provide speed in histogram for only good alignment super heroes ,title should be "distribution of speed" , xlabel should be "speed"

# %%
#histo = good_alignment.groupby(['Name', 'Speed'])['Speed'].max().nlargest(5)
#histo.hist(figsize=(10,5),title='Distribution of Speed', sharex=True)
plt.figure(figsize=(10,5))
plt.title=('Distribution of Speed')
plt.hist(good_alignment['Speed'])
plt.xlabel=("Speed")
plt.show()

# %% [markdown]
# # 21. Draw a histogram for combat of super villains having fig size 10,5 , provide combat in histogram for only bad alignment super heroes ,title should be "distribution of combat" , xlabel should be "combat"

# %%
plt.figure(figsize=(10,5))
plt.title=('Distribution of Combat')
plt.hist(Villans['Combat'])
plt.xlabel=("Combat")
plt.show()
